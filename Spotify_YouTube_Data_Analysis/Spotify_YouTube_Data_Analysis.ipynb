# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"/content/Spotify_Youtube_Dataset.csv", engine='python', on_bad_lines='skip', encoding='latin1')

# %%
data
# Out:
#       Unnamed: 0             Artist  \
# 0              0           Gorillaz
# 1              1           Gorillaz
# 2              2           Gorillaz
# 3              3           Gorillaz
# 4              4           Gorillaz
# ...          ...                ...
# 7219        7219        John Powell
# 7220        7220        John Powell
# 7221        7221  Armand Van Helden
# 7222        7222  Armand Van Helden
# 7223        7223  Armand Van Helden
#
#                                             Url_spotify  \
# 0     https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1     https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2     https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3     https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4     https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                 ...
# 7219  https://open.spotify.com/artist/3EAHF3jdnHHdko...
# 7220  https://open.spotify.com/artist/3EAHF3jdnHHdko...
# 7221  https://open.spotify.com/artist/3cQA9WH8liZfej...
# 7222  https://open.spotify.com/artist/3cQA9WH8liZfej...
# 7223  https://open.spotify.com/artist/3cQA9WH8liZfej...
#
#                                               Track  \
# 0                                    Feel Good Inc.
# 1                                   Rhinestone Eyes
# 2     New Gold (feat. Tame Impala and Bootie Brown)
# 3                                On Melancholy Hill
# 4                                    Clint Eastwood
# ...                                             ...
# 7219                                P.S. I Love You
# 7220                             Coming Back Around
# 7221                                        Bonkers
# 7222                   Wings (I Won't Let You Down)
# 7223                                       My My My
#
#                                                   Album Album_type  \
# 0                                            Demon Days      album
# 1                                         Plastic Beach      album
# 2         New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                         Plastic Beach      album
# 4                                              Gorillaz      album
# ...                                                 ...        ...
# 7219                                    P.S. I Love You      album
# 7220  How To Train Your Dragon (Music From The Motio...      album
# 7221            Tongue N' Cheek (Dirtee Deluxe Edition)      album
# 7222                       Wings (I Won't Let You Down)     single
# 7223                                             Nympho      album
#
#                                        Uri  Danceability  Energy   Key  ...  \
# 0     spotify:track:0d28khcov6AiegSCpG5TuT         0.818  0.7050   6.0  ...
# 1     spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676  0.7030   8.0  ...
# 2     spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695  0.9230   1.0  ...
# 3     spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689  0.7390   2.0  ...
# 4     spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663  0.6940  10.0  ...
# ...                                    ...           ...     ...   ...  ...
# 7219  spotify:track:17xHXgJeDJyynbXy3qoAeW         0.462  0.0294   0.0  ...
# 7220  spotify:track:0prLNHPLzTyroOlmWjyluS         0.351  0.8120   4.0  ...
# 7221  spotify:track:6ddQ5KCkvCggk3j6KdA0zL         0.624  0.9770  11.0  ...
# 7222  spotify:track:0QZyAYqpbsfnBfZ4vMRSVd         0.692  0.8560   1.0  ...
# 7223  spotify:track:653rxW1E7V52QWh6a7oIdS         0.652  0.7330   7.0  ...
#
#                                       Url_youtube  \
# 0     https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     https://www.youtube.com/watch?v=yYDmaexVHic
# 2     https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     https://www.youtube.com/watch?v=1V_xRb0x9aw
# ...                                           ...
# 7219  https://www.youtube.com/watch?v=-bxXoLXYa0k
# 7220  https://www.youtube.com/watch?v=O5GE5UvF9ZI
# 7221  https://www.youtube.com/watch?v=MgpWJq6f2GI
# 7222  https://www.youtube.com/watch?v=YMVM-irrK7Y
# 7223  https://www.youtube.com/watch?v=uLllyFfFKUY
#
#                                                   Title  \
# 0            Gorillaz - Feel Good Inc. (Official Video)
# 1     Gorillaz - Rhinestone Eyes [Storyboard Film] (...
# 2     Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3        Gorillaz - On Melancholy Hill (Official Video)
# 4            Gorillaz - Clint Eastwood (Official Video)
# ...                                                 ...
# 7219                                    P.S. I Love You
# 7220                                 Coming Back Around
# 7221  Dizzee Rascal - Bonkers (Feat. Armand Van Held...
# 7222  Armand Van Helden x Karen Harding - Wings (I W...
# 7223                     Armand Van Helden   My, My, My
#
#                     Channel        Views      Likes  Comments  \
# 0                  Gorillaz  693555221.0  6220896.0  169907.0
# 1                  Gorillaz   72011645.0  1079128.0   31003.0
# 2                  Gorillaz    8435055.0   282142.0    7399.0
# 3                  Gorillaz  211754952.0  1788577.0   55229.0
# 4                  Gorillaz  618480958.0  6197318.0  155930.0
# ...                     ...          ...        ...       ...
# 7219    John Powell - Topic      38040.0      338.0       4.0
# 7220    John Powell - Topic    1296264.0    19397.0      99.0
# 7221      Weedy Weed Smoker       4623.0       58.0       0.0
# 7222       Spinnin' Records     118831.0     3218.0      82.0
# 7223  áá¥áááá¥á§      80649.0      817.0      13.0
#
#                                             Description  Licensed  \
# 0     Official HD Video for Gorillaz' fantastic trac...      True
# 1     The official video for Gorillaz - Rhinestone E...      True
# 2     Gorillaz - New Gold ft. Tame Impala & Bootie B...      True
# 3     Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# 4     The official music video for Gorillaz - Clint ...      True
# ...                                                 ...       ...
# 7219  Provided to YouTube by Universal Music Group\n...      True
# 7220  Provided to YouTube by Universal Music Group\n...      True
# 7221  Music video by Dizzee Rascal featuring Armand ...     False
# 7222  Armand Van Helden x Karen Harding - Wings (I W...      True
# 7223                                                NaN     False
#
#      official_video        Stream
# 0              True  1.040235e+09
# 1              True  3.100837e+08
# 2              True  6.306347e+07
# 3              True  4.346636e+08
# 4              True  6.172597e+08
# ...             ...           ...
# 7219           True  1.318177e+07
# 7220           True  1.016846e+07
# 7221          False  1.445380e+08
# 7222           True  2.753011e+06
# 7223          False  6.118252e+07
#
# [7224 rows x 28 columns]

# %%
data.columns                   # to show the names of columns of the dataframe
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
data.info()                   # to get some basic information about the datset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7224 entries, 0 to 7223
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7224 non-null   int64
#  1   Artist            7224 non-null   object
#  2   Url_spotify       7224 non-null   object
#  3   Track             7224 non-null   object
#  4   Album             7224 non-null   object
#  5   Album_type        7224 non-null   object
#  6   Uri               7224 non-null   object
#  7   Danceability      7224 non-null   float64
#  8   Energy            7224 non-null   float64
#  9   Key               7224 non-null   float64
#  10  Loudness          7224 non-null   float64
#  11  Speechiness       7224 non-null   float64
#  12  Acousticness      7224 non-null   float64
#  13  Instrumentalness  7224 non-null   float64
#  14  Liveness          7224 non-null   float64
#  15  Valence           7224 non-null   float64
#  16  Tempo             7224 non-null   float64
#  17  Duration_ms       7224 non-null   float64
#  18  Url_youtube       7081 non-null   object
#  19  Title             7081 non-null   object
#  20  Channel           7081 non-null   object
#  21  Views             7081 non-null   float64
#  22  Likes             7044 non-null   float64
#  23  Comments          7049 non-null   float64
#  24  Description       6890 non-null   object
#  25  Licensed          7081 non-null   object
#  26  official_video    7081 non-null   object
#  27  Stream            6963 non-null   float64
# dtypes: float64(15), int64(1), object(12)
# memory usage: 1.5+ MB

# %%
# removing the columns from the dataframe

data.drop(columns = ['Unnamed: 0', 'Url_spotify', 'Uri', 'Url_youtube'], inplace = True)

# %%
data
# Out:
#                  Artist                                          Track  \
# 0              Gorillaz                                 Feel Good Inc.
# 1              Gorillaz                                Rhinestone Eyes
# 2              Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3              Gorillaz                             On Melancholy Hill
# 4              Gorillaz                                 Clint Eastwood
# ...                 ...                                            ...
# 7219        John Powell                                P.S. I Love You
# 7220        John Powell                             Coming Back Around
# 7221  Armand Van Helden                                        Bonkers
# 7222  Armand Van Helden                   Wings (I Won't Let You Down)
# 7223  Armand Van Helden                                       My My My
#
#                                                   Album Album_type  \
# 0                                            Demon Days      album
# 1                                         Plastic Beach      album
# 2         New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                         Plastic Beach      album
# 4                                              Gorillaz      album
# ...                                                 ...        ...
# 7219                                    P.S. I Love You      album
# 7220  How To Train Your Dragon (Music From The Motio...      album
# 7221            Tongue N' Cheek (Dirtee Deluxe Edition)      album
# 7222                       Wings (I Won't Let You Down)     single
# 7223                                             Nympho      album
#
#       Danceability  Energy   Key  Loudness  Speechiness  Acousticness  ...  \
# 0            0.818  0.7050   6.0    -6.679       0.1770      0.008360  ...
# 1            0.676  0.7030   8.0    -5.815       0.0302      0.086900  ...
# 2            0.695  0.9230   1.0    -3.930       0.0522      0.042500  ...
# 3            0.689  0.7390   2.0    -5.810       0.0260      0.000015  ...
# 4            0.663  0.6940  10.0    -8.627       0.1710      0.025300  ...
# ...            ...     ...   ...       ...          ...           ...  ...
# 7219         0.462  0.0294   0.0   -28.156       0.0481      0.996000  ...
# 7220         0.351  0.8120   4.0    -7.498       0.0699      0.111000  ...
# 7221         0.624  0.9770  11.0    -3.340       0.2200      0.006150  ...
# 7222         0.692  0.8560   1.0    -2.963       0.0351      0.074600  ...
# 7223         0.652  0.7330   7.0    -8.207       0.2460      0.006720  ...
#
#       Duration_ms                                              Title  \
# 0        222640.0         Gorillaz - Feel Good Inc. (Official Video)
# 1        200173.0  Gorillaz - Rhinestone Eyes [Storyboard Film] (...
# 2        215150.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3        233867.0     Gorillaz - On Melancholy Hill (Official Video)
# 4        340920.0         Gorillaz - Clint Eastwood (Official Video)
# ...           ...                                                ...
# 7219      83293.0                                    P.S. I Love You
# 7220     171227.0                                 Coming Back Around
# 7221     177573.0  Dizzee Rascal - Bonkers (Feat. Armand Van Held...
# 7222     171905.0  Armand Van Helden x Karen Harding - Wings (I W...
# 7223     182267.0                     Armand Van Helden   My, My, My
#
#                     Channel        Views      Likes  Comments  \
# 0                  Gorillaz  693555221.0  6220896.0  169907.0
# 1                  Gorillaz   72011645.0  1079128.0   31003.0
# 2                  Gorillaz    8435055.0   282142.0    7399.0
# 3                  Gorillaz  211754952.0  1788577.0   55229.0
# 4                  Gorillaz  618480958.0  6197318.0  155930.0
# ...                     ...          ...        ...       ...
# 7219    John Powell - Topic      38040.0      338.0       4.0
# 7220    John Powell - Topic    1296264.0    19397.0      99.0
# 7221      Weedy Weed Smoker       4623.0       58.0       0.0
# 7222       Spinnin' Records     118831.0     3218.0      82.0
# 7223  áá¥áááá¥á§      80649.0      817.0      13.0
#
#                                             Description  Licensed  \
# 0     Official HD Video for Gorillaz' fantastic trac...      True
# 1     The official video for Gorillaz - Rhinestone E...      True
# 2     Gorillaz - New Gold ft. Tame Impala & Bootie B...      True
# 3     Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# 4     The official music video for Gorillaz - Clint ...      True
# ...                                                 ...       ...
# 7219  Provided to YouTube by Universal Music Group\n...      True
# 7220  Provided to YouTube by Universal Music Group\n...      True
# 7221  Music video by Dizzee Rascal featuring Armand ...     False
# 7222  Armand Van Helden x Karen Harding - Wings (I W...      True
# 7223                                                NaN     False
#
#       official_video        Stream
# 0               True  1.040235e+09
# 1               True  3.100837e+08
# 2               True  6.306347e+07
# 3               True  4.346636e+08
# 4               True  6.172597e+08
# ...              ...           ...
# 7219            True  1.318177e+07
# 7220            True  1.016846e+07
# 7221           False  1.445380e+08
# 7222            True  2.753011e+06
# 7223           False  6.118252e+07
#
# [7224 rows x 24 columns]

# %%
# checking missing values counts in each column of the dataframe

data.isna().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Title               143
# Channel             143
# Views               143
# Likes               180
# Comments            175
# Description         334
# Licensed            143
# official_video      143
# Stream              261
# dtype: int64

# %%
# filling the missing values with 0 in Likes & Commnets column

data['Likes'] =  data['Likes'].fillna(0)
data['Comments'] = data['Comments'].fillna(0)

# %%
data.isnull().sum()     # to check the count of missing values in each column
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Title               143
# Channel             143
# Views               143
# Likes                 0
# Comments              0
# Description         334
# Licensed            143
# official_video      143
# Stream              261
# dtype: int64

# %%
data.dropna(inplace = True)               # It drops the rows that contains all or any missing values

# %%
data.isnull().sum()     # to check the count of missing values in each column
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6644 entries, 0 to 7222
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            6644 non-null   object
#  1   Track             6644 non-null   object
#  2   Album             6644 non-null   object
#  3   Album_type        6644 non-null   object
#  4   Danceability      6644 non-null   float64
#  5   Energy            6644 non-null   float64
#  6   Key               6644 non-null   float64
#  7   Loudness          6644 non-null   float64
#  8   Speechiness       6644 non-null   float64
#  9   Acousticness      6644 non-null   float64
#  10  Instrumentalness  6644 non-null   float64
#  11  Liveness          6644 non-null   float64
#  12  Valence           6644 non-null   float64
#  13  Tempo             6644 non-null   float64
#  14  Duration_ms       6644 non-null   float64
#  15  Title             6644 non-null   object
#  16  Channel           6644 non-null   object
#  17  Views             6644 non-null   float64
#  18  Likes             6644 non-null   float64
#  19  Comments          6644 non-null   float64
#  20  Description       6644 non-null   object
#  21  Licensed          6644 non-null   object
#  22  official_video    6644 non-null   object
#  23  Stream            6644 non-null   float64
# dtypes: float64(15), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Q.1) Top 10 Artists - with the Highest Views on YouTube?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# 1      True            True  3.100837e+08
#
# [2 rows x 24 columns]

# %%
Artist_grouped =  data.groupby('Artist')['Views'].sum()

# %%
Artist_grouped
# Out:
# Artist
# *NSYNC           1.027833e+09
# 112              2.191345e+08
# 21 Savage        1.718228e+08
# 2Pac             1.092522e+09
# 3 Doors Down     1.527164e+09
#                      ...
# blink-182        1.451952e+09
# kevoxx           4.246572e+07
# mor ve Ã¶tesi    2.207599e+08
# thasup           7.073185e+07
# Ãejo            6.266808e+08
# Name: Views, Length: 718, dtype: float64

# %%
Artist_sorted =  Artist_grouped.sort_values(ascending = False)

# %%
Artist_sorted.head(10)
# Out:
# Artist
# Luis Fonsi            1.162811e+10
# Daddy Yankee          1.086828e+10
# Coldplay              9.997278e+09
# Eminem                9.119324e+09
# Enrique Iglesias      8.860271e+09
# Shakira               8.818140e+09
# Sia                   8.441835e+09
# Farruko               7.125613e+09
# Earth, Wind & Fire    6.414077e+09
# Nicky Jam             6.321868e+09
# Name: Views, dtype: float64

# %% [markdown]
# #### Q.2) Top 10 Tracks - with the Highest Streams on Spotify?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...     222640.0
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
x = data[['Track', 'Stream']]          # creating a new dataframe with 2 columns - Track & Stream

x
# Out:
#                                               Track        Stream
# 0                                    Feel Good Inc.  1.040235e+09
# 1                                   Rhinestone Eyes  3.100837e+08
# 2     New Gold (feat. Tame Impala and Bootie Brown)  6.306347e+07
# 3                                On Melancholy Hill  4.346636e+08
# 4                                    Clint Eastwood  6.172597e+08
# ...                                             ...           ...
# 7217                           Forbidden Friendship  2.521683e+07
# 7219                                P.S. I Love You  1.318177e+07
# 7220                             Coming Back Around  1.016846e+07
# 7221                                        Bonkers  1.445380e+08
# 7222                   Wings (I Won't Let You Down)  2.753011e+06
#
# [6644 rows x 2 columns]

# %%
most_stream_track =  x.sort_values(by = ['Stream'], ascending=False).head(10) # sorting the dataframe wrt Stream column

# %%
most_stream_track
# Out:
#                          Track        Stream
# 140       lovely (with Khalid)  2.110574e+09
# 43    Something Just Like This  2.030826e+09
# 1151         Despacito - Remix  1.593688e+09
# 569    Wonderwall - Remastered  1.568357e+09
# 124            Till I Collapse  1.548872e+09
# 254              Cheap Thrills  1.538447e+09
# 365                  Despacito  1.506598e+09
# 1147                 Despacito  1.506598e+09
# 40                      Yellow  1.483622e+09
# 1777      Don't Stop Believin'  1.466430e+09

# %% [markdown]
# ### Question For You -
#
# Q.2A) 5 Tracks - with the Lowest Streams on Spotify?

# %% [markdown]
# #### Q.3) What are the most common Album Types on Spotify? How many tracks belong to each album type?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...     222640.0
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
data.Album_type.unique()              # to check the unique values in a column
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
a_type =  data['Album_type'].value_counts()     # It shows all unique values with their counts in the column

a_type
# Out:
# Album_type
# album          5466
# single          775
# compilation     403
# Name: count, dtype: int64

# %%
# draw a Pie chart

plt.pie( a_type, labels =  a_type.index, autopct = "‘%1.1f%%’", startangle= 60 ,
        colors= 'myr', shadow='True', explode = (0.05,0.05,0.05),  pctdistance = 0.75)

plt.show()

# %% [markdown]
# Pie Chart                          -
# plt.pie(slices, labels= activities, colors = ‘bryg’, startangle= , shadow=True, explode=(0,0,0.1,0.2), autopct= ‘%1.1f%%’, pctdistance=0.75 ) .
#
# Slices = [12,15,20,10] ,
#
# activities = [‘eating’, ‘ sleeping’ , ‘working’, ‘playing’].
#
# #Explode – To cut the slices out.
#
# Autopct – To show the % on the chart using string format.
#
# pctdistance – Distance of % from center
#
# #Compare parts of data to the whole. It shows the size of items(wedges) in one data series proportional to the sum of the items.

# %% [markdown]
# #### Q.4) How do the Average Views, Likes, and Comments are compared between different Album Types?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...     222640.0
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
# group the Album Type column, and show the mean of three columns

df = data.groupby('Album_type')[['Likes', 'Views', 'Comments']].mean()

df
# Out:
#                      Likes         Views      Comments
# Album_type
# album        451336.906879  8.055187e+07  16292.359129
# compilation  410620.940447  6.670556e+07  15643.205955
# single       531871.798710  6.960601e+07  17102.538065

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.reset_index()                # rest_index - To convert the index of a Series into a column to form a DataFrame

df
# Out:
#     Album_type          Likes         Views      Comments
# 0        album  451336.906879  8.055187e+07  16292.359129
# 1  compilation  410620.940447  6.670556e+07  15643.205955
# 2       single  531871.798710  6.960601e+07  17102.538065

# %%
# melt - unpivot a dataframe

df_melted  = pd.melt( df, id_vars = 'Album_type', var_name = "Attribute", value_name = 'Total' )

df_melted
# Out:
#     Album_type Attribute         Total
# 0        album     Likes  4.513369e+05
# 1  compilation     Likes  4.106209e+05
# 2       single     Likes  5.318718e+05
# 3        album     Views  8.055187e+07
# 4  compilation     Views  6.670556e+07
# 5       single     Views  6.960601e+07
# 6        album  Comments  1.629236e+04
# 7  compilation  Comments  1.564321e+04
# 8       single  Comments  1.710254e+04

# %%
# Draw the Bar Plot

plt.figure(figsize = (9,4))

sns.barplot( x = 'Album_type', y = 'Total', hue = 'Attribute', data = df_melted );

# %% [markdown]
# #### Q.5) Top 5 YouTube Channels -  based on the Views?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...     222640.0
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
c_views = data.groupby('Channel')['Views'].sum().sort_values(ascending=False).head()

c_views
# Out:
# Channel
# LuisFonsiVEVO          1.945685e+10
# T-Series               1.531615e+10
# EminemVEVO             8.810791e+09
# EnriqueIglesiasVEVO    8.729674e+09
# shakiraVEVO            8.421020e+09
# Name: Views, dtype: float64

# %%
c_views = c_views.reset_index()

c_views.head(10)
# Out:
#                Channel         Views
# 0        LuisFonsiVEVO  1.945685e+10
# 1             T-Series  1.531615e+10
# 2           EminemVEVO  8.810791e+09
# 3  EnriqueIglesiasVEVO  8.729674e+09
# 4          shakiraVEVO  8.421020e+09

# %%
type(c_views)
# Out:
# pandas.core.frame.DataFrame

# %%
# sns.set_style("whitegrid")

sns.barplot( x = "Views", y = "Channel", data = c_views, color='black')
plt.title('Top 5 Channels by Views')
plt.xlabel('Views')
plt.ylabel('Channel')
plt.show()

# %% [markdown]
# #### Q.6) The Top Most Track -  based on Views?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# 1      True            True  3.100837e+08
#
# [2 rows x 24 columns]

# %%
data.sort_values( by = 'Views', ascending = False).head(1)
# Out:
#           Artist      Track Album Album_type  Danceability  Energy  Key  \
# 1147  Luis Fonsi  Despacito  VIDA      album         0.655   0.797  2.0
#
#       Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 1147    -4.787        0.153         0.198  ...     229360.0
#
#                                         Title        Channel         Views  \
# 1147  Luis Fonsi - Despacito ft. Daddy Yankee  LuisFonsiVEVO  8.079649e+09
#
#            Likes   Comments  \
# 1147  50788652.0  4252791.0
#
#                                             Description  Licensed  \
# 1147  âDespacitoâ disponible ya en todas las pla...      True
#
#       official_video        Stream
# 1147            True  1.506598e+09
#
# [1 rows x 24 columns]

# %% [markdown]
# #### Q.7) Which Top 7 Tracks have the highest Like-to-View ratio on YouTube?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...     222640.0
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
track_lv = data[['Track', 'Likes', 'Views']].copy()
track_lv['LV_Ratio'] = track_lv['Likes']/track_lv['Views'] * 100

# %%
# This cell is now redundant as LV_Ratio is created in the previous cell. I will leave it empty.

# %%
# This cell was attempting to drop the LV_Ratio column, which is not the desired action. I will leave it empty.

# %%
track_lv
# Out:
#                                               Track      Likes        Views
# 0                                    Feel Good Inc.  6220896.0  693555221.0
# 1                                   Rhinestone Eyes  1079128.0   72011645.0
# 2     New Gold (feat. Tame Impala and Bootie Brown)   282142.0    8435055.0
# 3                                On Melancholy Hill  1788577.0  211754952.0
# 4                                    Clint Eastwood  6197318.0  618480958.0
# ...                                             ...        ...          ...
# 7217                           Forbidden Friendship    44916.0    4458706.0
# 7219                                P.S. I Love You      338.0      38040.0
# 7220                             Coming Back Around    19397.0    1296264.0
# 7221                                        Bonkers       58.0       4623.0
# 7222                   Wings (I Won't Let You Down)     3218.0     118831.0
#
# [6644 rows x 3 columns]

# %%
track_lv.sort_values( by = 'LV_Ratio', ascending = False).head(7)
# Out:
#                                 Track    Likes     Views   LV_Ratio
# 1520  r()t()nda (feat. Tiziano Ferro)  11048.0   91142.0  12.121744
# 6440       Pack a Lunch (with Redman)   9307.0   96380.0   9.656568
# 2552             Castles Made of Sand  12703.0  131571.0   9.654863
# 6976                    Vur YÃ¼reÄim  33990.0  355826.0   9.552422
# 5462              Enter the Metaverse     25.0     275.0   9.090909
# 1067                             Raid  86055.0  986916.0   8.719587
# 757         Toc Toc (feat. Timbaland)  70607.0  878121.0   8.040691

# %%
track_lv.sort_values( by = 'LV_Ratio', ascending = False).head(7)
# Out:
#                                 Track    Likes     Views   LV_Ratio
# 1520  r()t()nda (feat. Tiziano Ferro)  11048.0   91142.0  12.121744
# 6440       Pack a Lunch (with Redman)   9307.0   96380.0   9.656568
# 2552             Castles Made of Sand  12703.0  131571.0   9.654863
# 6976                    Vur YÃ¼reÄim  33990.0  355826.0   9.552422
# 5462              Enter the Metaverse     25.0     275.0   9.090909
# 1067                             Raid  86055.0  986916.0   8.719587
# 757         Toc Toc (feat. Timbaland)  70607.0  878121.0   8.040691

# %% [markdown]
# #### Q.7.A) Which Top 3 Tracks have the lowest Like-to-View ratio on YouTube?

# %%
track_lv.sort_values(by='LV_Ratio', ascending=True).head(3)
# Out:
#                        Track  Likes       Views  LV_Ratio
# 4871       Do the Propeller!    0.0  28891826.0       0.0
# 6585            ã¢ã«ã·ã¢    0.0  68440668.0       0.0
# 4866  Miss Polly Had a Dolly    0.0  41901002.0       0.0

# %%
data['LV_Ratio'] = data['Likes'] / data['Views'] * 100
album_type_lv_ratio = data.groupby('Album_type')['LV_Ratio'].mean().reset_index()
display(album_type_lv_ratio)
# Out:
#     Album_type  LV_Ratio
# 0        album  0.884559
# 1  compilation  0.986686
# 2       single  1.490337

# %% [markdown]
# #### Q.8) Top Albums having the Tracks with Maximum Danceability ?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  \
# 0    -6.679        0.177       0.00836  ...
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#   Licensed  official_video        Stream  LV_Ratio
# 0     True            True  1.040235e+09  0.896958
#
# [1 rows x 25 columns]

# %%
# creating groups for each Album

T_danceability =  data.groupby('Album')['Danceability'].sum().sort_values(ascending=False)

T_danceability
# Out:
# Album
# Greatest Hits                                     12.5580
# The Score (Expanded Edition)                      10.5630
# I Am L.V.                                          7.5600
# Madvillainy                                        6.9190
# Folge 152: und das Geheimnis der Kelly BrÃ¼der     6.2580
#                                                    ...
# The Greatest Video Game Music 2                    0.0673
# Barber: Adagio for Strings                         0.0640
# The Three Tenors - The Best of the 3 Tenors        0.0000
# Hello, Dolly! (Remastered)                         0.0000
# Israeli Salad                                      0.0000
# Name: Danceability, Length: 4256, dtype: float64

# %%
data[data.Album == 'Greatest Hits']          # filtering the dataframe with 'Greatest Hits'
# Out:
#                                Artist  \
# 220                              2Pac
# 222                              2Pac
# 225                              2Pac
# 268                     Fleetwood Mac
# 1232                Bruce Springsteen
# 1236                Bruce Springsteen
# 1862                     Shania Twain
# 2164                      Wyclef Jean
# 3079                    Tracy Chapman
# 3097                          Blondie
# 3147                    Willie ColÃ³n
# 3578                       Eurythmics
# 3579                       Eurythmics
# 3580                       Eurythmics
# 3598                      Snow Patrol
# 3836                     James Taylor
# 3842                     James Taylor
# 4324  Tom Petty and the Heartbreakers
# 5185                   Gloria Estefan
# 6721                          Kenny G
#
#                                                   Track          Album  \
# 220                         Hit 'Em Up - Single Version  Greatest Hits
# 222                  California Love - Original Version  Greatest Hits
# 225                                             Changes  Greatest Hits
# 268                                               Gypsy  Greatest Hits
# 1232              Streets of Philadelphia - Single Edit  Greatest Hits
# 1236                                      Secret Garden  Greatest Hits
# 1862          From This Moment On - Pop On-Tour Version  Greatest Hits
# 2164                    Killing Me Softly With His Song  Greatest Hits
# 3079  Stand by Me - Live at the Late Show with David...  Greatest Hits
# 3097                                              Maria  Greatest Hits
# 3147                                     El Gran VarÃ³n  Greatest Hits
# 3578                    Sweet Dreams (Are Made of This)  Greatest Hits
# 3579     There Must Be an Angel (Playing With My Heart)  Greatest Hits
# 3580                                    Miracle of Love  Greatest Hits
# 3598                                       Just Say Yes  Greatest Hits
# 3836                                Carolina in My Mind  Greatest Hits
# 3842                     Something in the Way She Moves  Greatest Hits
# 4324                             Mary Jane's Last Dance  Greatest Hits
# 5185                                              Conga  Greatest Hits
# 6721  How Could an Angel Break My Heart (with Toni B...  Greatest Hits
#
#        Album_type  Danceability  Energy  Key  Loudness  Speechiness  \
# 220   compilation         0.916   0.844  7.0    -3.967       0.2360
# 222   compilation         0.763   0.850  7.0    -3.052       0.0417
# 225   compilation         0.865   0.665  7.0    -6.289       0.0730
# 268   compilation         0.622   0.540  5.0   -13.990       0.0261
# 1232  compilation         0.741   0.290  5.0   -13.251       0.0302
# 1236  compilation         0.520   0.329  0.0   -14.224       0.0266
# 1862  compilation         0.460   0.505  9.0    -5.487       0.0266
# 2164  compilation         0.765   0.437  4.0   -10.122       0.0727
# 3079  compilation         0.816   0.144  7.0   -10.148       0.0398
# 3097  compilation         0.548   0.800  9.0    -6.926       0.0597
# 3147  compilation         0.645   0.665  7.0    -5.519       0.0384
# 3578  compilation         0.710   0.472  8.0   -15.985       0.0498
# 3579  compilation         0.545   0.663  0.0   -11.360       0.0455
# 3580  compilation         0.529   0.472  2.0   -12.526       0.0264
# 3598  compilation         0.535   0.883  9.0    -5.456       0.0330
# 3836  compilation         0.579   0.267  4.0   -15.110       0.0348
# 3842  compilation         0.447   0.186  0.0   -17.369       0.0322
# 4324  compilation         0.464   0.655  7.0    -9.058       0.0608
# 5185  compilation         0.791   0.860  2.0    -8.282       0.0451
# 6721  compilation         0.297   0.230  5.0   -16.015       0.0358
#
#       Acousticness  ...                                              Title  \
# 220         0.0394  ...         2Pac - Hit 'Em Up (Dirty) (Music Video) HD
# 222         0.0304  ...  2Pac ft. Dr. Dre - California Love (Official V...
# 225         0.0453  ...                2pac - Changes Original Music Video
# 268         0.0170  ...       Fleetwood Mac - Gypsy (Official Music Video)
# 1232        0.2940  ...  Bruce Springsteen - Streets of Philadelphia (O...
# 1236        0.5760  ...  Bruce Springsteen Secret Garden HD, Jerry Magu...
# 1862        0.4200  ...          From This Moment On (Pop On-Tour Version)
# 2164        0.0271  ...  Fugees - Killing Me Softly With His Song (Offi...
# 3079        0.7970  ...  Tracy Chapman - Stand by Me (Live on Letterman...
# 3097        0.0380  ...                                    Maria - Blondie
# 3147        0.5810  ...         (willy colon el gran varon,(original).mpeg
# 3578        0.2960  ...  Eurythmics, Annie Lennox, Dave Stewart - Sweet...
# 3579        0.3560  ...  There Must Be An Angel (Playing With My Heart)...
# 3580        0.3130  ...  Eurythmics, Annie Lennox, Dave Stewart - Mirac...
# 3598        0.0214  ...        Snow Patrol - Just Say Yes (Official Video)
# 3836        0.1180  ...   Carolina In My Mind - James Taylor - Lyrics / HD
# 3842        0.2830  ...  James Taylor - Something In The Way She Moves ...
# 4324        0.0272  ...  Tom Petty And The Heartbreakers - Mary Jane's ...
# 5185        0.1180  ...        Gloria Estefan, Miami Sound Machine - Conga
# 6721        0.2730  ...  Toni Braxton - How Could An Angel Break My Hea...
#
#                    Channel        Views      Likes  Comments  \
# 220          Seven Hip-Hop  585712131.0  4363164.0  208460.0
# 222           UPROXX Video   84654029.0   484619.0   12875.0
# 225               The Best     306542.0     4350.0     305.0
# 268          Fleetwood Mac   81512369.0   436530.0   17764.0
# 1232  BruceSpringsteenVEVO  171514802.0   669935.0   25407.0
# 1236                    VJ   25696359.0   104022.0    4674.0
# 1862  Shania Twain - Topic    2629831.0    30669.0      65.0
# 2164         TheFugeesVEVO  351401822.0  2549466.0   42859.0
# 3079  Tracy Chapman Online   16971605.0   134753.0       0.0
# 3097             Paola1311   70126379.0   263063.0    9124.0
# 3147              fernel17     365531.0     3892.0     226.0
# 3578        EurythmicsVEVO  763534682.0  6430665.0  221508.0
# 3579        EurythmicsVEVO   37150247.0   248173.0   10256.0
# 3580        EurythmicsVEVO   31391217.0   219858.0    7682.0
# 3598        SnowPatrolVEVO   36198740.0   124427.0    5415.0
# 3836         Roadvideo 404    1774157.0    14808.0     879.0
# 3842          James Taylor     404157.0     5941.0     249.0
# 4324          TomPettyVEVO   43989902.0   294874.0   12666.0
# 5185     GloriaEstefanVEVO   31857094.0   330290.0   11886.0
# 6721       ToniBraxtonVEVO   36492038.0   193314.0    6585.0
#
#                                             Description Licensed  \
# 220   Music video by 2Pac performing Hit 'Em Up (Dir...    False
# 222   2Pac ft. Dr. Dre - California Love (Full Video...    False
# 225                 2pac - Changes Original Music Video    False
# 268   You're watching the official music video for F...     True
# 1232  Official Video of âStreets Of Philadelphia" ...     True
# 1236  My music video of Bruce Springsteen's beautifu...    False
# 1862  Provided to YouTube by Universal Music Group\n...     True
# 2164  "Killing Me Softly With His Song" by Fugees\n\...     True
# 3079  â¥ Subscribe our newsletter âº https://www.a...    False
# 3097                                     Blondie, Maria    False
# 3147                                                       False
# 3578  Eurythmics -Â Sweet Dreams (Are Made Of This) ...     True
# 3579  Eurythmics - There Must Be An Angel (Playing W...     True
# 3580  Eurythmics - Miracle Of Love (Official Video)\...     True
# 3598  Snow Patrol - Just Say Yes (Official Video)\n\...     True
# 3836                Disclaimer : For Entertainment Only    False
# 3842  In this restored footage James performs his so...     True
# 4324  REMASTERED IN HD!\n\nMusic video by Tom Petty ...     True
# 5185  Watch the official music video for "Conga" by ...     True
# 6721  Official HD music video for "How Could an Ange...     True
#
#       official_video       Stream  LV_Ratio
# 220            False  375955728.0  0.744933
# 222            False  497213287.0  0.572470
# 225            False  411056377.0  1.419055
# 268             True  213673856.0  0.535538
# 1232            True  239663934.0  0.390599
# 1236           False   69059523.0  0.404812
# 1862            True   84623227.0  1.166197
# 2164            True  518080621.0  0.725513
# 3079           False   44060055.0  0.793991
# 3097           False   90857487.0  0.375127
# 3147           False  114764427.0  1.064752
# 3578            True   14943362.0  0.842223
# 3579            True   63464225.0  0.668025
# 3580            True   38401127.0  0.700381
# 3598            True   72665878.0  0.343733
# 3836           False  113315832.0  0.834650
# 3842            True   31811854.0  1.469973
# 4324            True  256341255.0  0.670322
# 5185            True  199693647.0  1.036786
# 6721            True   44171549.0  0.529743
#
# [20 rows x 25 columns]

# %% [markdown]
# #### Q.9) What is the Correlation between Views, Likes, Comments, and Stream?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705  6.0
#
#    Loudness  Speechiness  Acousticness  ...  \
# 0    -6.679        0.177       0.00836  ...
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#   Licensed  official_video        Stream  LV_Ratio
# 0     True            True  1.040235e+09  0.896958
#
# [1 rows x 25 columns]

# %%
# creating a new dataframe with 4 columns

df_vlcs = data[['Views', 'Likes', 'Comments', 'Stream']]

df_vlcs
# Out:
#             Views      Likes  Comments        Stream
# 0     693555221.0  6220896.0  169907.0  1.040235e+09
# 1      72011645.0  1079128.0   31003.0  3.100837e+08
# 2       8435055.0   282142.0    7399.0  6.306347e+07
# 3     211754952.0  1788577.0   55229.0  4.346636e+08
# 4     618480958.0  6197318.0  155930.0  6.172597e+08
# ...           ...        ...       ...           ...
# 7217    4458706.0    44916.0     534.0  2.521683e+07
# 7219      38040.0      338.0       4.0  1.318177e+07
# 7220    1296264.0    19397.0      99.0  1.016846e+07
# 7221       4623.0       58.0       0.0  1.445380e+08
# 7222     118831.0     3218.0      82.0  2.753011e+06
#
# [6644 rows x 4 columns]

# %%
df_vlcs.corr()                      # correlation matrix for the required columns
# Out:
#              Views     Likes  Comments    Stream
# Views     1.000000  0.940067  0.849388  0.547811
# Likes     0.940067  1.000000  0.895994  0.573137
# Comments  0.849388  0.895994  1.000000  0.374426
# Stream    0.547811  0.573137  0.374426  1.000000

# %%
sns.heatmap(df_vlcs.corr())            # drawing a heatmap for the correlation matrix
# Out:
# <Axes: >

# %% [markdown]
# --------
